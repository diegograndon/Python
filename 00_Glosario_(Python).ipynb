# %% [markdown]
# <a href="https://colab.research.google.com/github/diegograndon/Python/blob/main/00_Glosario_(Python).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Glosario
#
# 1. División entera (`//`)
#
# >Es la división entre números en donde el resultado es siempre entero por tanto se redondea al entero menor.
#
# ---
#
# 2. Expresión
#
# >Una colección de operadores y números.
#
# ---
#
# 3. Valor
#
# >Es el resultado de una expresión
#
# ----
#
# 4. Error: SyntaxError
#
# >Ocurre cuando llamo una función y cometo un error en su escritura (por ejemplo: abs 42, es un error pues no puse los parentesis en el 42)
